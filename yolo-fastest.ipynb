# %% [markdown]
# # 創建資料夾

# %%
import os
import shutil 

if not os.path.exists("voc_detection"):
    os.mkdir("voc_detection")
    
if not os.path.exists("voc_detection/cfg"):
    os.mkdir("voc_detection/cfg") 
    os.mkdir("voc_detection/weights")

# %%
# %cd voc_detection

# %% [markdown]
# # 下載 voc dataset

# %%
! wget http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar

# %%
! tar xvf VOCtrainval_11-May-2012.tar
# Out:
# VOCdevkit/
# VOCdevkit/VOC2012/
# VOCdevkit/VOC2012/Annotations/
# VOCdevkit/VOC2012/Annotations/2007_000027.xml
# VOCdevkit/VOC2012/Annotations/2007_000032.xml
# VOCdevkit/VOC2012/Annotations/2007_000033.xml
# VOCdevkit/VOC2012/Annotations/2007_000039.xml
# VOCdevkit/VOC2012/Annotations/2007_000042.xml
# VOCdevkit/VOC2012/Annotations/2007_000061.xml
# VOCdevkit/VOC2012/Annotations/2007_000063.xml
# VOCdevkit/VOC2012/Annotations/2007_000068.xml
# VOCdevkit/VOC2012/Annotations/2007_000121.xml
# VOCdevkit/VOC2012/Annotations/2007_000123.xml
# VOCdevkit/VOC2012/Annotations/2007_000129.xml
# VOCdevkit/VOC2012/Annotations/2007_000170.xml
# VOCdevkit/VOC2012/Annotations/2007_000175.xml
# VOCdevkit/VOC2012/Annotations/2007_000187.xml
# VOCdevkit/VOC2012/Annotations/2007_000241.xml
# VOCdevkit/VOC2012/Annotations/2007_000243.xml
# VOCdevkit/VOC2012/Annotations/2007_000250.xml
# VOCdevkit/VOC2012/Annotations/2007_000256.xml
# VOCdevkit/VOC2012/Annotations/2007_000272.xml
# ...

# %% [markdown]
# # 下載 Yolo-Fastest

# %%
# %cd ..

# %%
! git clone https://github.com/dog-qiuqiu/Yolo-Fastest

# %%
if not os.path.exists("voc_detection/cfg/voc.data"):
    shutil.copyfile("Yolo-Fastest/data/voc.data", "voc_detection/cfg/voc.data")

if not os.path.exists("voc_detection/cfg/voc.names"):
    shutil.copyfile("Yolo-Fastest/data/voc.names", "voc_detection/cfg/voc.names")

# %%
! head voc_detection/cfg/voc.data
# Out:
# classes= 20
# train  = /home/pjreddie/data/voc/train.txt
# valid  = /home/pjreddie/data/voc/2007_test.txt
# names = data/voc.names
# backup = /home/pjreddie/backup/

# %%
# 更改 voc.data

# %%
! head voc_detection/cfg/voc.data
# Out:
# classes= 20
# train  = ../voc_detection/cfg/train.txt
# valid  = ../voc_detection/cfg/val.txt
# names = ../voc_detection/cfg/voc.names
# backup = ../voc_detection/weights

# %%
! cp Yolo-Fastest/data/voc.names voc_detection/cfg/voc_classes.txt

# %%
! cp Yolo-Fastest/Yolo-Fastest/VOC/yolo-fastest.cfg voc_detection/cfg/yolo-fastest.cfg

# %%
! sed -n -e 4p -e 5p -e 6p -e 834p -e 841p -e 910p -e 917p voc_detection/cfg/yolo-fastest.cfg
# Out:
# width=320
# height=320
# channels=3
# filters=75
# classes=20
# filters=75
# classes=20

# %%
! cp Yolo-Fastest/Yolo-Fastest/VOC/yolo-fastest.weights voc_detection/cfg/yolo-fastest.weights

# %% [markdown]
# # voc_convert_to_yolo

# %%
! pip install alfred-py
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 81.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 706 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 98 kB 7.6 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 5.5 MB 8.2 MB/s eta 0:00:01     |███████                         | 1.2 MB 8.2 MB/s eta 0:00:01
# ...
#   Created wheel for alfred-py: filename=alfred_py-2.8.4-py3-none-any.whl size=1762820 sha256=55cc5c460727498c38844171d32ce0940ccfcb47ab91a19657a1de11bc3e42f4
#   Stored in directory: /tmp/user-pip/wheels/e0/f4/74/027cf5d75a2f7ceb82dfeded37d22ebefe9d22b7411fc3ba3a
# ...
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7665 sha256=d7d9b4287e6825be0eb21244c094a8b2ae3159eef637b2257cdc3b4fb0377803
#   Stored in directory: /tmp/user-pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built alfred-py contextvars
# ...

# %%
! pip install pascal_voc_writer

# %%
# 查看 voc2yolo 需要的參數
! alfred data voc2yolo -h
# Out:
# usage: alfred data voc2yolo [-h] [--image_dir IMAGE_DIR] [--xml_dir XML_DIR]
#                             [--class_file CLASS_FILE]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --image_dir IMAGE_DIR, -i IMAGE_DIR
#                         Root of images dir (images/).
#   --xml_dir XML_DIR, -x XML_DIR
#                         Root of XML files.
#   --class_file CLASS_FILE, -c CLASS_FILE
#                         classes name file.

# %%
! alfred data voc2yolo -i voc_detection/VOCdevkit/VOC2012/JPEGImages -x voc_detection/VOCdevkit/VOC2012/Annotations -c voc_detection/cfg/voc_classes.txt
# Out:
# ----------------------------------------------------------------------
#               Alfred - Valet of Artificial Intelligence.
#          Author : 😀    Lucas Jin
#          Contact: 😍    wechat: jintianiloveu
#          At     : 👉    2020.11.01, since 2019.11.11
#          Loc    : 👉    Shenzhen, China
#          Star   : 👍    http://github.com/jinfagang/alfred
#          Ver.   : 👍    2.8.2
# ----------------------------------------------------------------------
#
#
#
# => Module: data
# => Action: voc2yolo
# INFO 12.25 15:30:16 alfred.py:505: start convert VOC to yolo... images root: voc_detection/VOCdevkit/VOC2012/JPEGImages, text root: voc_detection/VOCdevkit/VOC2012/Annotations
# labels dir to save: voc_detection/VOCdevkit/VOC2012/yolo_converted_from_voc
# Done!
# ...

# %%
! mv voc_detection/VOCdevkit/VOC2012/yolo_converted_from_voc voc_detection/VOCdevkit/VOC2012/labels

# %% [markdown]
# # Darknet

# %%
! git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 14648 (delta 0), reused 2 (delta 0), pack-reused 14645
# Receiving objects: 100% (14648/14648), 13.22 MiB | 7.22 MiB/s, done.
# Resolving deltas: 100% (9966/9966), done.
# Checking out files: 100% (2027/2027), done.

# %%
# %cd darknet

# %%
! head Makefile
# Out:
# GPU=0
# CUDNN=0
# CUDNN_HALF=0
# OPENCV=0
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0

# %% [markdown]
# ## 修改 Makefile
# - GPU=1
# - CUDNN=1
# - OPENCV=1

# %%
! sed -i "s/GPU=0/GPU=1/g" darknet/Makefile
! sed -i "s/CUDNN=0/CUDNN=1/g" darknet/Makefile
! sed -i "s/CUDNN_HALF=0/CUDNN_HALF=1/g" darknet/Makefile
! sed -i "s/OPENCV=0/OPENCV=1/g" darknet/Makefile

# %%
! head Makefile
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=1
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0

# %% [markdown]
# ## 編譯

# %%
! make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# ## 產生 pre-trained weights

# %%
! ./darknet partial ../voc_detection/cfg/yolo-fastest.cfg ../voc_detection/cfg/yolo-fastest.weights ../voc_detection/cfg/yolo-fastest.conv.109 109
# Out:
#  CUDA-version: 11010 (11010), cuDNN: 8.0.4, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.4.0
#  GPU isn't used
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv      8       3 x 3/ 2    320 x 320 x   3 ->  160 x 160 x   8 0.011 BF
#    1 conv      8       1 x 1/ 1    160 x 160 x   8 ->  160 x 160 x   8 0.003 BF
#    2 conv      8/   8  3 x 3/ 1    160 x 160 x   8 ->  160 x 160 x   8 0.004 BF
#    3 conv      4       1 x 1/ 1    160 x 160 x   8 ->  160 x 160 x   4 0.002 BF
#    4 conv      8       1 x 1/ 1    160 x 160 x   4 ->  160 x 160 x   8 0.002 BF
#    5 conv      8/   8  3 x 3/ 1    160 x 160 x   8 ->  160 x 160 x   8 0.004 BF
#    6 conv      4       1 x 1/ 1    160 x 160 x   8 ->  160 x 160 x   4 0.002 BF
#    7 dropout    p = 0.150        102400  ->   102400
#    8 Shortcut Layer: 3,  wt = 0, wn = 0, outputs: 160 x 160 x   4 0.000 BF
# ...

# %% [markdown]
# ## 訓練模型

# %%
! ./darknet detector train ../voc_detection/cfg/voc.data ../voc_detection/cfg/yolo-fastest.cfg ../voc_detection/cfg/yolo-fastest.conv.109 -dont_show
